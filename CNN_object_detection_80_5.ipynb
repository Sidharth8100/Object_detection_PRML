# %%
# # Import necessary libraries
# import tensorflow as tf
# from tensorflow.keras.datasets import cifar10
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten, Dropout
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import LearningRateScheduler
# import numpy as np
# import matplotlib.pyplot as plt

# # Load CIFAR-10 dataset
# (x_train, y_train), (x_test, y_test) = cifar10.load_data()

# # Normalize pixel values to be between 0 and 1
# x_train = x_train.astype('float32') / 255.0
# x_test = x_test.astype('float32') / 255.0

# # One-hot encode the labels
# y_train = tf.keras.utils.to_categorical(y_train, 10)
# y_test = tf.keras.utils.to_categorical(y_test, 10)

# # Define learning rate schedule
# def lr_schedule(epoch):
#     initial_lr = 0.001
#     drop_rate = 0.5
#     epochs_drop = 20.0
#     lr = initial_lr * (drop_rate ** (epoch // epochs_drop))
#     return lr

# # Create a callback for learning rate scheduling
# lr_scheduler = LearningRateScheduler(lr_schedule)

# # Define the model architecture - Deep ANN with 8 hidden layers
# model = Sequential([
#     Flatten(input_shape=(32, 32, 3)),
#     # First hidden layer
#     Dense(2048, activation='relu'),
#     Dropout(0.3),
#     # Second hidden layer
#     Dense(2048, activation='relu'),
#     Dropout(0.3),
#     # Third hidden layer
#     Dense(1536, activation='relu'),
#     Dropout(0.4),
#     # Fourth hidden layer
#     Dense(1024, activation='relu'),
#     Dropout(0.4),
#     # Fifth hidden layer
#     Dense(1024, activation='relu'),
#     Dropout(0.4),
#     # Sixth hidden layer
#     Dense(512, activation='relu'),
#     Dropout(0.5),
#     # Seventh hidden layer
#     Dense(512, activation='relu'),
#     Dropout(0.5),
#     # Eighth hidden layer
#     Dense(256, activation='relu'),
#     Dropout(0.5),
#     # Output layer
#     Dense(10, activation='softmax')
# ])

# # Compile the model
# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# # Display model summary
# model.summary()

# # Train the model
# history = model.fit(
#     x_train, y_train,
#     batch_size=128,
#     epochs=250,  # Train for 250 epochs to ensure reaching target accuracy
#     validation_data=(x_test, y_test),
#     callbacks=[lr_scheduler],
#     verbose=1
# )

# # Evaluate the model
# test_loss, test_acc = model.evaluate(x_test, y_test)
# print(f"Test accuracy: {test_acc*100:.2f}%")

# # Plot training & validation accuracy and loss
# plt.figure(figsize=(12, 5))

# # Accuracy plot
# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('Model Accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='lower right')

# # Loss plot
# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Model Loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='upper right')

# plt.tight_layout()
# plt.show()

# # Display final results
# final_train_acc = history.history['accuracy'][-1] * 100
# final_val_acc = history.history['val_accuracy'][-1] * 100
# print(f"Final training accuracy: {final_train_acc:.2f}%")
# print(f"Final validation accuracy: {final_val_acc:.2f}%")
# print(f"Test accuracy: {test_acc*100:.2f}%")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 2048)                │       6,293,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2048)                │       4,196,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1536)                │       3,147,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1536)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1024)                │       1,573,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,181,962 (65.54 MB)
#  Trainable params: 17,181,962 (65.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.1243 - loss: 2.3364 - val_accuracy: 0.1922 - val_loss: 2.0834 - learning_rate: 0.0010
# Epoch 2/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.1727 - loss: 2.1122 - val_accuracy: 0.1807 - val_loss: 2.1047 - learning_rate: 0.0010
# Epoch 3/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1759 - loss: 2.1068 - val_accuracy: 0.2019 - val_loss: 2.0570 - learning_rate: 0.0010
# Epoch 4/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1812 - loss: 2.0886 - val_accuracy: 0.1791 - val_loss: 2.0927 - learning_rate: 0.0010
# Epoch 5/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1788 - loss: 2.0828 - val_accuracy: 0.1949 - val_loss: 2.0703 - learning_rate: 0.0010
# Epoch 6/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1828 - loss: 2.0697 - val_accuracy: 0.1928 - val_loss: 2.0624 - learning_rate: 0.0010
# Epoch 7/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1878 - loss: 2.0722 - val_accuracy: 0.2115 - val_loss: 2.0227 - learning_rate: 0.0010
# Epoch 8/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2046 - loss: 2.0382 - val_accuracy: 0.2283 - val_loss: 1.9867 - learning_rate: 0.0010
# Epoch 9/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2115 - loss: 2.0413 - val_accuracy: 0.2138 - val_loss: 2.0385 - learning_rate: 0.0010
# Epoch 10/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2176 - loss: 2.0276 - val_accuracy: 0.2279 - val_loss: 2.0200 - learning_rate: 0.0010
# Epoch 11/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2220 - loss: 2.0221 - val_accuracy: 0.2342 - val_loss: 1.9952 - learning_rate: 0.0010
# Epoch 12/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2130 - loss: 2.0436 - val_accuracy: 0.1924 - val_loss: 2.0641 - learning_rate: 0.0010
# Epoch 13/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.1960 - loss: 2.0914 - val_accuracy: 0.2203 - val_loss: 2.0633 - learning_rate: 0.0010
# Epoch 14/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2031 - loss: 2.0730 - val_accuracy: 0.2397 - val_loss: 2.0083 - learning_rate: 0.0010
# Epoch 15/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.2194 - loss: 2.0289 - val_accuracy: 0.2508 - val_loss: 1.9798 - learning_rate: 0.0010
# Epoch 16/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2192 - loss: 2.0352 - val_accuracy: 0.2271 - val_loss: 2.0094 - learning_rate: 0.0010
# Epoch 17/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2130 - loss: 2.0522 - val_accuracy: 0.2418 - val_loss: 2.0095 - learning_rate: 0.0010
# Epoch 18/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2258 - loss: 2.0145 - val_accuracy: 0.2455 - val_loss: 1.9743 - learning_rate: 0.0010
# Epoch 19/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2190 - loss: 2.0457 - val_accuracy: 0.2434 - val_loss: 2.0032 - learning_rate: 0.0010
# Epoch 20/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2274 - loss: 2.0046 - val_accuracy: 0.2320 - val_loss: 1.9884 - learning_rate: 0.0010
# Epoch 21/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2276 - loss: 2.0052 - val_accuracy: 0.2397 - val_loss: 2.0181 - learning_rate: 5.0000e-04
# Epoch 22/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2335 - loss: 1.9867 - val_accuracy: 0.2361 - val_loss: 2.0212 - learning_rate: 5.0000e-04
# Epoch 23/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2348 - loss: 1.9793 - val_accuracy: 0.2451 - val_loss: 1.9998 - learning_rate: 5.0000e-04
# Epoch 24/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2405 - loss: 1.9787 - val_accuracy: 0.2461 - val_loss: 1.9995 - learning_rate: 5.0000e-04
# Epoch 25/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2365 - loss: 1.9754 - val_accuracy: 0.2624 - val_loss: 1.9775 - learning_rate: 5.0000e-04
# Epoch 26/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2448 - loss: 1.9720 - val_accuracy: 0.2141 - val_loss: 2.0497 - learning_rate: 5.0000e-04
# Epoch 27/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2384 - loss: 1.9887 - val_accuracy: 0.2520 - val_loss: 1.9706 - learning_rate: 5.0000e-04
# Epoch 28/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2419 - loss: 1.9613 - val_accuracy: 0.2492 - val_loss: 1.9906 - learning_rate: 5.0000e-04
# Epoch 29/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2440 - loss: 1.9683 - val_accuracy: 0.2485 - val_loss: 2.0008 - learning_rate: 5.0000e-04
# Epoch 30/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2494 - loss: 1.9571 - val_accuracy: 0.2442 - val_loss: 1.9927 - learning_rate: 5.0000e-04
# Epoch 31/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2479 - loss: 1.9566 - val_accuracy: 0.2574 - val_loss: 1.9775 - learning_rate: 5.0000e-04
# Epoch 32/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2495 - loss: 1.9502 - val_accuracy: 0.2482 - val_loss: 1.9894 - learning_rate: 5.0000e-04
# Epoch 33/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2478 - loss: 1.9468 - val_accuracy: 0.2231 - val_loss: 2.0502 - learning_rate: 5.0000e-04
# Epoch 34/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2492 - loss: 1.9512 - val_accuracy: 0.2402 - val_loss: 1.9919 - learning_rate: 5.0000e-04
# Epoch 35/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2468 - loss: 1.9603 - val_accuracy: 0.2469 - val_loss: 1.9886 - learning_rate: 5.0000e-04
# Epoch 36/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2475 - loss: 1.9526 - val_accuracy: 0.2334 - val_loss: 2.0303 - learning_rate: 5.0000e-04
# Epoch 37/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2450 - loss: 1.9598 - val_accuracy: 0.2640 - val_loss: 1.9592 - learning_rate: 5.0000e-04
# Epoch 38/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2534 - loss: 1.9453 - val_accuracy: 0.2525 - val_loss: 1.9890 - learning_rate: 5.0000e-04
# Epoch 39/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2498 - loss: 1.9515 - val_accuracy: 0.2526 - val_loss: 1.9917 - learning_rate: 5.0000e-04
# Epoch 40/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2568 - loss: 1.9404 - val_accuracy: 0.2621 - val_loss: 1.9773 - learning_rate: 5.0000e-04
# Epoch 41/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2587 - loss: 1.9340 - val_accuracy: 0.2630 - val_loss: 1.9721 - learning_rate: 2.5000e-04
# Epoch 42/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2629 - loss: 1.9193 - val_accuracy: 0.2617 - val_loss: 1.9619 - learning_rate: 2.5000e-04
# Epoch 43/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2602 - loss: 1.9291 - val_accuracy: 0.2414 - val_loss: 2.0007 - learning_rate: 2.5000e-04
# Epoch 44/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2555 - loss: 1.9348 - val_accuracy: 0.2483 - val_loss: 1.9982 - learning_rate: 2.5000e-04
# Epoch 45/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2623 - loss: 1.9200 - val_accuracy: 0.2618 - val_loss: 1.9517 - learning_rate: 2.5000e-04
# Epoch 46/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2638 - loss: 1.9191 - val_accuracy: 0.2607 - val_loss: 1.9625 - learning_rate: 2.5000e-04
# Epoch 47/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2605 - loss: 1.9236 - val_accuracy: 0.2620 - val_loss: 1.9761 - learning_rate: 2.5000e-04
# Epoch 48/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2626 - loss: 1.9142 - val_accuracy: 0.2561 - val_loss: 1.9730 - learning_rate: 2.5000e-04
# Epoch 49/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2650 - loss: 1.9199 - val_accuracy: 0.2695 - val_loss: 1.9567 - learning_rate: 2.5000e-04
# Epoch 50/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2688 - loss: 1.9181 - val_accuracy: 0.2606 - val_loss: 1.9634 - learning_rate: 2.5000e-04
# Epoch 51/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2628 - loss: 1.9184 - val_accuracy: 0.2454 - val_loss: 1.9874 - learning_rate: 2.5000e-04
# Epoch 52/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2623 - loss: 1.9192 - val_accuracy: 0.2603 - val_loss: 1.9632 - learning_rate: 2.5000e-04
# Epoch 53/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2664 - loss: 1.9072 - val_accuracy: 0.2660 - val_loss: 1.9647 - learning_rate: 2.5000e-04
# Epoch 54/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2746 - loss: 1.9043 - val_accuracy: 0.2489 - val_loss: 1.9925 - learning_rate: 2.5000e-04
# Epoch 55/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2719 - loss: 1.9062 - val_accuracy: 0.2790 - val_loss: 1.9431 - learning_rate: 2.5000e-04
# Epoch 56/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2762 - loss: 1.8983 - val_accuracy: 0.2731 - val_loss: 1.9632 - learning_rate: 2.5000e-04
# Epoch 57/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2764 - loss: 1.8921 - val_accuracy: 0.2831 - val_loss: 1.9485 - learning_rate: 2.5000e-04
# Epoch 58/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2798 - loss: 1.9003 - val_accuracy: 0.2788 - val_loss: 1.9409 - learning_rate: 2.5000e-04
# Epoch 59/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2789 - loss: 1.8860 - val_accuracy: 0.2888 - val_loss: 1.9295 - learning_rate: 2.5000e-04
# Epoch 60/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2783 - loss: 1.8864 - val_accuracy: 0.2841 - val_loss: 1.9307 - learning_rate: 2.5000e-04
# Epoch 61/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2782 - loss: 1.8859 - val_accuracy: 0.2894 - val_loss: 1.9396 - learning_rate: 1.2500e-04
# Epoch 62/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2853 - loss: 1.8685 - val_accuracy: 0.2914 - val_loss: 1.9375 - learning_rate: 1.2500e-04
# Epoch 63/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2874 - loss: 1.8694 - val_accuracy: 0.2909 - val_loss: 1.9268 - learning_rate: 1.2500e-04
# Epoch 64/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2809 - loss: 1.8741 - val_accuracy: 0.2824 - val_loss: 1.9426 - learning_rate: 1.2500e-04
# Epoch 65/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2855 - loss: 1.8663 - val_accuracy: 0.2871 - val_loss: 1.9327 - learning_rate: 1.2500e-04
# Epoch 66/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2899 - loss: 1.8677 - val_accuracy: 0.2866 - val_loss: 1.9269 - learning_rate: 1.2500e-04
# Epoch 67/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2838 - loss: 1.8712 - val_accuracy: 0.2868 - val_loss: 1.9232 - learning_rate: 1.2500e-04
# Epoch 68/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2895 - loss: 1.8631 - val_accuracy: 0.2958 - val_loss: 1.9131 - learning_rate: 1.2500e-04
# Epoch 69/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2892 - loss: 1.8654 - val_accuracy: 0.2932 - val_loss: 1.9246 - learning_rate: 1.2500e-04
# Epoch 70/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2914 - loss: 1.8638 - val_accuracy: 0.2850 - val_loss: 1.9197 - learning_rate: 1.2500e-04
# Epoch 71/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2916 - loss: 1.8640 - val_accuracy: 0.2966 - val_loss: 1.9123 - learning_rate: 1.2500e-04
# Epoch 72/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2921 - loss: 1.8574 - val_accuracy: 0.2884 - val_loss: 1.9233 - learning_rate: 1.2500e-04
# Epoch 73/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2936 - loss: 1.8618 - val_accuracy: 0.2865 - val_loss: 1.9265 - learning_rate: 1.2500e-04
# Epoch 74/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2904 - loss: 1.8629 - val_accuracy: 0.2931 - val_loss: 1.9239 - learning_rate: 1.2500e-04
# Epoch 75/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2956 - loss: 1.8550 - val_accuracy: 0.2971 - val_loss: 1.9084 - learning_rate: 1.2500e-04
# Epoch 76/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2948 - loss: 1.8559 - val_accuracy: 0.2938 - val_loss: 1.9239 - learning_rate: 1.2500e-04
# Epoch 77/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2956 - loss: 1.8543 - val_accuracy: 0.2922 - val_loss: 1.9332 - learning_rate: 1.2500e-04
# Epoch 78/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2954 - loss: 1.8555 - val_accuracy: 0.2934 - val_loss: 1.9180 - learning_rate: 1.2500e-04
# Epoch 79/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.2992 - loss: 1.8524 - val_accuracy: 0.2955 - val_loss: 1.9093 - learning_rate: 1.2500e-04
# Epoch 80/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3021 - loss: 1.8442 - val_accuracy: 0.2918 - val_loss: 1.9196 - learning_rate: 1.2500e-04
# Epoch 81/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2974 - loss: 1.8447 - val_accuracy: 0.2976 - val_loss: 1.9097 - learning_rate: 6.2500e-05
# Epoch 82/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2983 - loss: 1.8480 - val_accuracy: 0.2950 - val_loss: 1.9207 - learning_rate: 6.2500e-05
# Epoch 83/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2991 - loss: 1.8421 - val_accuracy: 0.2951 - val_loss: 1.9278 - learning_rate: 6.2500e-05
# Epoch 84/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2992 - loss: 1.8469 - val_accuracy: 0.2967 - val_loss: 1.9174 - learning_rate: 6.2500e-05
# Epoch 85/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3006 - loss: 1.8437 - val_accuracy: 0.2998 - val_loss: 1.9083 - learning_rate: 6.2500e-05
# Epoch 86/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3022 - loss: 1.8376 - val_accuracy: 0.2995 - val_loss: 1.9118 - learning_rate: 6.2500e-05
# Epoch 87/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3002 - loss: 1.8427 - val_accuracy: 0.2966 - val_loss: 1.9190 - learning_rate: 6.2500e-05
# Epoch 88/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3038 - loss: 1.8403 - val_accuracy: 0.3004 - val_loss: 1.9231 - learning_rate: 6.2500e-05
# Epoch 89/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2983 - loss: 1.8401 - val_accuracy: 0.3061 - val_loss: 1.8934 - learning_rate: 6.2500e-05
# Epoch 90/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2993 - loss: 1.8419 - val_accuracy: 0.3075 - val_loss: 1.9007 - learning_rate: 6.2500e-05
# Epoch 91/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2978 - loss: 1.8456 - val_accuracy: 0.3068 - val_loss: 1.8992 - learning_rate: 6.2500e-05
# Epoch 92/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3011 - loss: 1.8392 - val_accuracy: 0.3011 - val_loss: 1.9057 - learning_rate: 6.2500e-05
# Epoch 93/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3020 - loss: 1.8415 - val_accuracy: 0.3050 - val_loss: 1.9038 - learning_rate: 6.2500e-05
# Epoch 94/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3025 - loss: 1.8379 - val_accuracy: 0.3050 - val_loss: 1.9186 - learning_rate: 6.2500e-05
# Epoch 95/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3023 - loss: 1.8376 - val_accuracy: 0.3024 - val_loss: 1.9127 - learning_rate: 6.2500e-05
# Epoch 96/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3040 - loss: 1.8347 - val_accuracy: 0.3106 - val_loss: 1.8991 - learning_rate: 6.2500e-05
# Epoch 97/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3040 - loss: 1.8396 - val_accuracy: 0.3037 - val_loss: 1.9138 - learning_rate: 6.2500e-05
# Epoch 98/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3052 - loss: 1.8303 - val_accuracy: 0.3147 - val_loss: 1.8956 - learning_rate: 6.2500e-05
# Epoch 99/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3055 - loss: 1.8350 - val_accuracy: 0.3043 - val_loss: 1.9097 - learning_rate: 6.2500e-05
# Epoch 100/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3058 - loss: 1.8316 - val_accuracy: 0.3000 - val_loss: 1.9088 - learning_rate: 6.2500e-05
# Epoch 101/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3029 - loss: 1.8302 - val_accuracy: 0.3030 - val_loss: 1.9123 - learning_rate: 3.1250e-05
# Epoch 102/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3022 - loss: 1.8317 - val_accuracy: 0.3041 - val_loss: 1.9088 - learning_rate: 3.1250e-05
# Epoch 103/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3048 - loss: 1.8324 - val_accuracy: 0.3048 - val_loss: 1.9099 - learning_rate: 3.1250e-05
# Epoch 104/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3085 - loss: 1.8278 - val_accuracy: 0.3027 - val_loss: 1.9109 - learning_rate: 3.1250e-05
# Epoch 105/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3021 - loss: 1.8361 - val_accuracy: 0.3053 - val_loss: 1.9070 - learning_rate: 3.1250e-05
# Epoch 106/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3078 - loss: 1.8249 - val_accuracy: 0.3072 - val_loss: 1.9060 - learning_rate: 3.1250e-05
# Epoch 107/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3081 - loss: 1.8323 - val_accuracy: 0.3050 - val_loss: 1.9046 - learning_rate: 3.1250e-05
# Epoch 108/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3054 - loss: 1.8312 - val_accuracy: 0.3069 - val_loss: 1.9001 - learning_rate: 3.1250e-05
# Epoch 109/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3102 - loss: 1.8227 - val_accuracy: 0.3026 - val_loss: 1.9041 - learning_rate: 3.1250e-05
# Epoch 110/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3073 - loss: 1.8279 - val_accuracy: 0.3003 - val_loss: 1.9090 - learning_rate: 3.1250e-05
# Epoch 111/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3094 - loss: 1.8266 - val_accuracy: 0.2973 - val_loss: 1.9133 - learning_rate: 3.1250e-05
# Epoch 112/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3078 - loss: 1.8253 - val_accuracy: 0.3027 - val_loss: 1.9085 - learning_rate: 3.1250e-05
# Epoch 113/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3086 - loss: 1.8301 - val_accuracy: 0.3048 - val_loss: 1.9049 - learning_rate: 3.1250e-05
# Epoch 114/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3107 - loss: 1.8235 - val_accuracy: 0.3064 - val_loss: 1.9042 - learning_rate: 3.1250e-05
# Epoch 115/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3082 - loss: 1.8305 - val_accuracy: 0.3017 - val_loss: 1.9030 - learning_rate: 3.1250e-05
# Epoch 116/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3092 - loss: 1.8254 - val_accuracy: 0.3047 - val_loss: 1.8968 - learning_rate: 3.1250e-05
# Epoch 117/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3097 - loss: 1.8202 - val_accuracy: 0.3065 - val_loss: 1.8982 - learning_rate: 3.1250e-05
# Epoch 118/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3086 - loss: 1.8180 - val_accuracy: 0.3036 - val_loss: 1.9067 - learning_rate: 3.1250e-05
# Epoch 119/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3090 - loss: 1.8235 - val_accuracy: 0.2995 - val_loss: 1.9147 - learning_rate: 3.1250e-05
# Epoch 120/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3124 - loss: 1.8226 - val_accuracy: 0.3001 - val_loss: 1.9091 - learning_rate: 3.1250e-05
# Epoch 121/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3126 - loss: 1.8178 - val_accuracy: 0.3036 - val_loss: 1.9076 - learning_rate: 1.5625e-05
# Epoch 122/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3085 - loss: 1.8202 - val_accuracy: 0.3028 - val_loss: 1.9078 - learning_rate: 1.5625e-05
# Epoch 123/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3128 - loss: 1.8211 - val_accuracy: 0.3045 - val_loss: 1.9050 - learning_rate: 1.5625e-05
# Epoch 124/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3093 - loss: 1.8253 - val_accuracy: 0.3051 - val_loss: 1.9037 - learning_rate: 1.5625e-05
# Epoch 125/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3080 - loss: 1.8266 - val_accuracy: 0.3027 - val_loss: 1.9054 - learning_rate: 1.5625e-05
# Epoch 126/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3120 - loss: 1.8222 - val_accuracy: 0.3046 - val_loss: 1.9052 - learning_rate: 1.5625e-05
# Epoch 127/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3130 - loss: 1.8234 - val_accuracy: 0.3055 - val_loss: 1.9057 - learning_rate: 1.5625e-05
# Epoch 128/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3078 - loss: 1.8211 - val_accuracy: 0.2997 - val_loss: 1.9146 - learning_rate: 1.5625e-05
# Epoch 129/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3094 - loss: 1.8167 - val_accuracy: 0.3043 - val_loss: 1.9065 - learning_rate: 1.5625e-05
# Epoch 130/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3099 - loss: 1.8182 - val_accuracy: 0.3028 - val_loss: 1.9060 - learning_rate: 1.5625e-05
# Epoch 131/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3111 - loss: 1.8216 - val_accuracy: 0.3040 - val_loss: 1.9107 - learning_rate: 1.5625e-05
# Epoch 132/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3090 - loss: 1.8249 - val_accuracy: 0.3085 - val_loss: 1.8988 - learning_rate: 1.5625e-05
# Epoch 133/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3120 - loss: 1.8191 - val_accuracy: 0.3061 - val_loss: 1.9045 - learning_rate: 1.5625e-05
# Epoch 134/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3134 - loss: 1.8150 - val_accuracy: 0.3049 - val_loss: 1.9046 - learning_rate: 1.5625e-05
# Epoch 135/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3100 - loss: 1.8225 - val_accuracy: 0.3067 - val_loss: 1.9060 - learning_rate: 1.5625e-05
# Epoch 136/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3098 - loss: 1.8233 - val_accuracy: 0.3108 - val_loss: 1.8963 - learning_rate: 1.5625e-05
# Epoch 137/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3098 - loss: 1.8260 - val_accuracy: 0.3060 - val_loss: 1.9050 - learning_rate: 1.5625e-05
# Epoch 138/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3154 - loss: 1.8112 - val_accuracy: 0.3042 - val_loss: 1.9047 - learning_rate: 1.5625e-05
# Epoch 139/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3142 - loss: 1.8228 - val_accuracy: 0.3082 - val_loss: 1.9004 - learning_rate: 1.5625e-05
# Epoch 140/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3150 - loss: 1.8146 - val_accuracy: 0.3056 - val_loss: 1.9018 - learning_rate: 1.5625e-05
# Epoch 141/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3110 - loss: 1.8197 - val_accuracy: 0.3057 - val_loss: 1.9024 - learning_rate: 7.8125e-06
# Epoch 142/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3170 - loss: 1.8142 - val_accuracy: 0.3048 - val_loss: 1.9064 - learning_rate: 7.8125e-06
# Epoch 143/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3142 - loss: 1.8251 - val_accuracy: 0.3075 - val_loss: 1.9021 - learning_rate: 7.8125e-06
# Epoch 144/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3112 - loss: 1.8210 - val_accuracy: 0.3067 - val_loss: 1.9041 - learning_rate: 7.8125e-06
# Epoch 145/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3150 - loss: 1.8151 - val_accuracy: 0.3069 - val_loss: 1.9009 - learning_rate: 7.8125e-06
# Epoch 146/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3138 - loss: 1.8120 - val_accuracy: 0.3044 - val_loss: 1.9036 - learning_rate: 7.8125e-06
# Epoch 147/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3133 - loss: 1.8151 - val_accuracy: 0.3052 - val_loss: 1.9058 - learning_rate: 7.8125e-06
# Epoch 148/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3129 - loss: 1.8157 - val_accuracy: 0.3076 - val_loss: 1.9016 - learning_rate: 7.8125e-06
# Epoch 149/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3119 - loss: 1.8211 - val_accuracy: 0.3065 - val_loss: 1.9032 - learning_rate: 7.8125e-06
# Epoch 150/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3170 - loss: 1.8113 - val_accuracy: 0.3076 - val_loss: 1.9040 - learning_rate: 7.8125e-06
# Epoch 151/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3143 - loss: 1.8172 - val_accuracy: 0.3071 - val_loss: 1.9042 - learning_rate: 7.8125e-06
# Epoch 152/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3171 - loss: 1.8181 - val_accuracy: 0.3065 - val_loss: 1.9065 - learning_rate: 7.8125e-06
# Epoch 153/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3185 - loss: 1.8190 - val_accuracy: 0.3065 - val_loss: 1.9053 - learning_rate: 7.8125e-06
# Epoch 154/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3157 - loss: 1.8117 - val_accuracy: 0.3072 - val_loss: 1.9043 - learning_rate: 7.8125e-06
# Epoch 155/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3156 - loss: 1.8141 - val_accuracy: 0.3061 - val_loss: 1.9065 - learning_rate: 7.8125e-06
# Epoch 156/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3097 - loss: 1.8164 - val_accuracy: 0.3066 - val_loss: 1.9055 - learning_rate: 7.8125e-06
# Epoch 157/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3129 - loss: 1.8214 - val_accuracy: 0.3069 - val_loss: 1.9028 - learning_rate: 7.8125e-06
# Epoch 158/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3164 - loss: 1.8063 - val_accuracy: 0.3056 - val_loss: 1.9078 - learning_rate: 7.8125e-06
# Epoch 159/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3154 - loss: 1.8194 - val_accuracy: 0.3065 - val_loss: 1.9011 - learning_rate: 7.8125e-06
# Epoch 160/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3145 - loss: 1.8164 - val_accuracy: 0.3077 - val_loss: 1.9013 - learning_rate: 7.8125e-06
# Epoch 161/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3146 - loss: 1.8102 - val_accuracy: 0.3084 - val_loss: 1.9026 - learning_rate: 3.9063e-06
# Epoch 162/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3179 - loss: 1.8079 - val_accuracy: 0.3082 - val_loss: 1.9030 - learning_rate: 3.9063e-06
# Epoch 163/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3125 - loss: 1.8067 - val_accuracy: 0.3094 - val_loss: 1.9008 - learning_rate: 3.9063e-06
# Epoch 164/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3139 - loss: 1.8179 - val_accuracy: 0.3077 - val_loss: 1.9024 - learning_rate: 3.9063e-06
# Epoch 165/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3151 - loss: 1.8207 - val_accuracy: 0.3089 - val_loss: 1.9003 - learning_rate: 3.9063e-06
# Epoch 166/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3133 - loss: 1.8196 - val_accuracy: 0.3084 - val_loss: 1.9005 - learning_rate: 3.9063e-06
# Epoch 167/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3189 - loss: 1.8127 - val_accuracy: 0.3083 - val_loss: 1.9013 - learning_rate: 3.9063e-06
# Epoch 168/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3198 - loss: 1.8139 - val_accuracy: 0.3080 - val_loss: 1.9018 - learning_rate: 3.9063e-06
# Epoch 169/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3164 - loss: 1.8092 - val_accuracy: 0.3081 - val_loss: 1.9026 - learning_rate: 3.9063e-06
# Epoch 170/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3206 - loss: 1.8100 - val_accuracy: 0.3090 - val_loss: 1.9012 - learning_rate: 3.9063e-06
# Epoch 171/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3202 - loss: 1.8152 - val_accuracy: 0.3093 - val_loss: 1.9001 - learning_rate: 3.9063e-06
# Epoch 172/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3200 - loss: 1.8107 - val_accuracy: 0.3088 - val_loss: 1.9007 - learning_rate: 3.9063e-06
# Epoch 173/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3162 - loss: 1.8098 - val_accuracy: 0.3074 - val_loss: 1.9017 - learning_rate: 3.9063e-06
# Epoch 174/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3181 - loss: 1.8140 - val_accuracy: 0.3073 - val_loss: 1.9010 - learning_rate: 3.9063e-06
# Epoch 175/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3140 - loss: 1.8162 - val_accuracy: 0.3075 - val_loss: 1.9029 - learning_rate: 3.9063e-06
# Epoch 176/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3141 - loss: 1.8168 - val_accuracy: 0.3089 - val_loss: 1.9002 - learning_rate: 3.9063e-06
# Epoch 177/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3132 - loss: 1.8159 - val_accuracy: 0.3076 - val_loss: 1.9016 - learning_rate: 3.9063e-06
# Epoch 178/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3163 - loss: 1.8077 - val_accuracy: 0.3079 - val_loss: 1.9022 - learning_rate: 3.9063e-06
# Epoch 179/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3151 - loss: 1.8131 - val_accuracy: 0.3071 - val_loss: 1.9035 - learning_rate: 3.9063e-06
# Epoch 180/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3193 - loss: 1.8074 - val_accuracy: 0.3075 - val_loss: 1.9020 - learning_rate: 3.9063e-06
# Epoch 181/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3198 - loss: 1.8067 - val_accuracy: 0.3076 - val_loss: 1.9022 - learning_rate: 1.9531e-06
# Epoch 182/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3180 - loss: 1.8179 - val_accuracy: 0.3079 - val_loss: 1.8998 - learning_rate: 1.9531e-06
# Epoch 183/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3118 - loss: 1.8175 - val_accuracy: 0.3085 - val_loss: 1.9019 - learning_rate: 1.9531e-06
# Epoch 184/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3235 - loss: 1.8084 - val_accuracy: 0.3081 - val_loss: 1.9012 - learning_rate: 1.9531e-06
# Epoch 185/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3174 - loss: 1.8177 - val_accuracy: 0.3082 - val_loss: 1.9013 - learning_rate: 1.9531e-06
# Epoch 186/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3162 - loss: 1.8124 - val_accuracy: 0.3080 - val_loss: 1.9009 - learning_rate: 1.9531e-06
# Epoch 187/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3168 - loss: 1.8131 - val_accuracy: 0.3078 - val_loss: 1.9011 - learning_rate: 1.9531e-06
# Epoch 188/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3181 - loss: 1.8056 - val_accuracy: 0.3079 - val_loss: 1.9009 - learning_rate: 1.9531e-06
# Epoch 189/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3192 - loss: 1.8130 - val_accuracy: 0.3081 - val_loss: 1.9017 - learning_rate: 1.9531e-06
# Epoch 190/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3188 - loss: 1.8100 - val_accuracy: 0.3077 - val_loss: 1.9019 - learning_rate: 1.9531e-06
# Epoch 191/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3164 - loss: 1.8146 - val_accuracy: 0.3080 - val_loss: 1.9028 - learning_rate: 1.9531e-06
# Epoch 192/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3164 - loss: 1.8182 - val_accuracy: 0.3084 - val_loss: 1.8993 - learning_rate: 1.9531e-06
# Epoch 193/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3223 - loss: 1.8085 - val_accuracy: 0.3088 - val_loss: 1.9005 - learning_rate: 1.9531e-06
# Epoch 194/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3154 - loss: 1.8131 - val_accuracy: 0.3082 - val_loss: 1.9007 - learning_rate: 1.9531e-06
# Epoch 195/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3177 - loss: 1.8106 - val_accuracy: 0.3083 - val_loss: 1.8993 - learning_rate: 1.9531e-06
# Epoch 196/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3143 - loss: 1.8170 - val_accuracy: 0.3088 - val_loss: 1.8998 - learning_rate: 1.9531e-06
# Epoch 197/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3169 - loss: 1.8094 - val_accuracy: 0.3087 - val_loss: 1.9003 - learning_rate: 1.9531e-06
# Epoch 198/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3192 - loss: 1.8112 - val_accuracy: 0.3080 - val_loss: 1.8988 - learning_rate: 1.9531e-06
# Epoch 199/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3156 - loss: 1.8082 - val_accuracy: 0.3086 - val_loss: 1.9004 - learning_rate: 1.9531e-06
# Epoch 200/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3177 - loss: 1.8116 - val_accuracy: 0.3090 - val_loss: 1.9009 - learning_rate: 1.9531e-06
# Epoch 201/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3183 - loss: 1.8052 - val_accuracy: 0.3087 - val_loss: 1.9007 - learning_rate: 9.7656e-07
# Epoch 202/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3166 - loss: 1.8198 - val_accuracy: 0.3081 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 203/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3185 - loss: 1.8147 - val_accuracy: 0.3083 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 204/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3175 - loss: 1.8025 - val_accuracy: 0.3080 - val_loss: 1.9002 - learning_rate: 9.7656e-07
# Epoch 205/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3165 - loss: 1.8157 - val_accuracy: 0.3087 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 206/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3201 - loss: 1.8048 - val_accuracy: 0.3081 - val_loss: 1.9000 - learning_rate: 9.7656e-07
# Epoch 207/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.3156 - loss: 1.8096 - val_accuracy: 0.3085 - val_loss: 1.9003 - learning_rate: 9.7656e-07
# Epoch 208/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3194 - loss: 1.8135 - val_accuracy: 0.3079 - val_loss: 1.8994 - learning_rate: 9.7656e-07
# Epoch 209/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3145 - loss: 1.8106 - val_accuracy: 0.3087 - val_loss: 1.8989 - learning_rate: 9.7656e-07
# Epoch 210/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3163 - loss: 1.8095 - val_accuracy: 0.3089 - val_loss: 1.8990 - learning_rate: 9.7656e-07
# Epoch 211/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3164 - loss: 1.8218 - val_accuracy: 0.3077 - val_loss: 1.8993 - learning_rate: 9.7656e-07
# Epoch 212/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3192 - loss: 1.8017 - val_accuracy: 0.3076 - val_loss: 1.8999 - learning_rate: 9.7656e-07
# Epoch 213/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3167 - loss: 1.8089 - val_accuracy: 0.3084 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 214/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3139 - loss: 1.8193 - val_accuracy: 0.3084 - val_loss: 1.8999 - learning_rate: 9.7656e-07
# Epoch 215/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3150 - loss: 1.8149 - val_accuracy: 0.3081 - val_loss: 1.9006 - learning_rate: 9.7656e-07
# Epoch 216/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3194 - loss: 1.8118 - val_accuracy: 0.3077 - val_loss: 1.9000 - learning_rate: 9.7656e-07
# Epoch 217/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3168 - loss: 1.8170 - val_accuracy: 0.3077 - val_loss: 1.9000 - learning_rate: 9.7656e-07
# Epoch 218/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3165 - loss: 1.8087 - val_accuracy: 0.3080 - val_loss: 1.8994 - learning_rate: 9.7656e-07
# Epoch 219/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3184 - loss: 1.8096 - val_accuracy: 0.3076 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 220/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3177 - loss: 1.8073 - val_accuracy: 0.3078 - val_loss: 1.9001 - learning_rate: 9.7656e-07
# Epoch 221/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3174 - loss: 1.8172 - val_accuracy: 0.3077 - val_loss: 1.8999 - learning_rate: 4.8828e-07
# Epoch 222/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3184 - loss: 1.8139 - val_accuracy: 0.3078 - val_loss: 1.8997 - learning_rate: 4.8828e-07
# Epoch 223/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3179 - loss: 1.8078 - val_accuracy: 0.3077 - val_loss: 1.8993 - learning_rate: 4.8828e-07
# Epoch 224/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3211 - loss: 1.8087 - val_accuracy: 0.3077 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 225/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3155 - loss: 1.8118 - val_accuracy: 0.3079 - val_loss: 1.9001 - learning_rate: 4.8828e-07
# Epoch 226/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3175 - loss: 1.8200 - val_accuracy: 0.3079 - val_loss: 1.8998 - learning_rate: 4.8828e-07
# Epoch 227/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3176 - loss: 1.8121 - val_accuracy: 0.3079 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 228/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3156 - loss: 1.8135 - val_accuracy: 0.3077 - val_loss: 1.8999 - learning_rate: 4.8828e-07
# Epoch 229/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3176 - loss: 1.8114 - val_accuracy: 0.3075 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 230/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3138 - loss: 1.8135 - val_accuracy: 0.3077 - val_loss: 1.8998 - learning_rate: 4.8828e-07
# Epoch 231/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3186 - loss: 1.8106 - val_accuracy: 0.3079 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 232/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3214 - loss: 1.8052 - val_accuracy: 0.3078 - val_loss: 1.8995 - learning_rate: 4.8828e-07
# Epoch 233/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3192 - loss: 1.8083 - val_accuracy: 0.3078 - val_loss: 1.8997 - learning_rate: 4.8828e-07
# Epoch 234/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3186 - loss: 1.8105 - val_accuracy: 0.3078 - val_loss: 1.8997 - learning_rate: 4.8828e-07
# Epoch 235/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3189 - loss: 1.8073 - val_accuracy: 0.3081 - val_loss: 1.8998 - learning_rate: 4.8828e-07
# Epoch 236/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.3169 - loss: 1.8153 - val_accuracy: 0.3084 - val_loss: 1.9000 - learning_rate: 4.8828e-07
# Epoch 237/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3149 - loss: 1.8174 - val_accuracy: 0.3084 - val_loss: 1.8999 - learning_rate: 4.8828e-07
# Epoch 238/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3211 - loss: 1.8092 - val_accuracy: 0.3086 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 239/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3207 - loss: 1.8067 - val_accuracy: 0.3086 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 240/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3126 - loss: 1.8143 - val_accuracy: 0.3085 - val_loss: 1.8996 - learning_rate: 4.8828e-07
# Epoch 241/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3167 - loss: 1.8092 - val_accuracy: 0.3086 - val_loss: 1.8994 - learning_rate: 2.4414e-07
# Epoch 242/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3165 - loss: 1.8116 - val_accuracy: 0.3082 - val_loss: 1.8995 - learning_rate: 2.4414e-07
# Epoch 243/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3192 - loss: 1.8059 - val_accuracy: 0.3082 - val_loss: 1.8994 - learning_rate: 2.4414e-07
# Epoch 244/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.3201 - loss: 1.8089 - val_accuracy: 0.3081 - val_loss: 1.8991 - learning_rate: 2.4414e-07
# Epoch 245/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3166 - loss: 1.8134 - val_accuracy: 0.3081 - val_loss: 1.8991 - learning_rate: 2.4414e-07
# Epoch 246/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3188 - loss: 1.8061 - val_accuracy: 0.3081 - val_loss: 1.8994 - learning_rate: 2.4414e-07
# Epoch 247/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3179 - loss: 1.8001 - val_accuracy: 0.3084 - val_loss: 1.8996 - learning_rate: 2.4414e-07
# Epoch 248/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3207 - loss: 1.8080 - val_accuracy: 0.3082 - val_loss: 1.8995 - learning_rate: 2.4414e-07
# Epoch 249/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3180 - loss: 1.8096 - val_accuracy: 0.3082 - val_loss: 1.8996 - learning_rate: 2.4414e-07
# Epoch 250/250
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3156 - loss: 1.8057 - val_accuracy: 0.3083 - val_loss: 1.8995 - learning_rate: 2.4414e-07
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3099 - loss: 1.8913
# Test accuracy: 30.83%
# Final training accuracy: 31.46%
# Final validation accuracy: 30.83%
# Test accuracy: 30.83%

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

print(f"Dataset loaded: {x_train.shape[0]} training samples, {x_test.shape[0]} test samples")

# Create a data generator for simple augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Define a simpler CNN model that still performs well
model = Sequential([
    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    Conv2D(32, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    # Fully Connected Layers
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)

# Model checkpoint
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max'
)

# Train the model
batch_size = 128
epochs = 50  # You'll likely need much fewer epochs to reach good performance

print("Starting training...")
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping, checkpoint],
    verbose=1
)

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.savefig('training_history.png')
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc*100:.2f}%")

# Class names for visualization
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Visualize some predictions
def plot_predictions(model, x, y_true, num_images=10):
    # Get predictions
    predictions = model.predict(x[:num_images])
    pred_labels = np.argmax(predictions, axis=1)
    true_labels = np.argmax(y_true[:num_images], axis=1)

    # Plot images with predictions
    plt.figure(figsize=(15, 6))
    for i in range(num_images):
        plt.subplot(2, 5, i+1)
        plt.imshow(x[i])
        color = 'green' if pred_labels[i] == true_labels[i] else 'red'
        plt.title(f"True: {class_names[true_labels[i]]}\nPred: {class_names[pred_labels[i]]}",
                  color=color)
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('predictions.png')
    plt.show()

# Show predictions on test set
print("Visualizing some test predictions:")
plot_predictions(model, x_test, y_test)

# Print confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get predictions
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Calculate confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('confusion_matrix.png')
plt.show()

print("\nTraining complete! Model evaluated and visualized.")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Dataset loaded: 50000 training samples, 10000 test samples
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,341,226 (5.12 MB)
#  Trainable params: 1,341,226 (5.12 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting training...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.2378 - loss: 2.0266
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 399s 1s/step - accuracy: 0.2380 - loss: 2.0261 - val_accuracy: 0.4624 - val_loss: 1.4760
# Epoch 2/50
#   1/390 ━━━━━━━━━━━━━━━━━━━━ 8:01 1s/step - accuracy: 0.3672 - loss: 1.6321
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.3672 - loss: 1.6321 - val_accuracy: 0.4765 - val_loss: 1.4429
# Epoch 3/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.4598 - loss: 1.4818
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 419s 1s/step - accuracy: 0.4599 - loss: 1.4817 - val_accuracy: 0.5604 - val_loss: 1.2136
# Epoch 4/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.4609 - loss: 1.4157 - val_accuracy: 0.5587 - val_loss: 1.2161
# Epoch 5/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.5383 - loss: 1.2770
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 388s 996ms/step - accuracy: 0.5383 - loss: 1.2769 - val_accuracy: 0.6526 - val_loss: 0.9769
# Epoch 6/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.5391 - loss: 1.2882 - val_accuracy: 0.6467 - val_loss: 0.9899
# Epoch 7/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.5917 - loss: 1.1398 - val_accuracy: 0.6321 - val_loss: 1.0597
# Epoch 8/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.6719 - loss: 0.9426 - val_accuracy: 0.6016 - val_loss: 1.1505
# Epoch 9/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.6220 - loss: 1.0590
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 421s 999ms/step - accuracy: 0.6221 - loss: 1.0590 - val_accuracy: 0.6809 - val_loss: 0.8952
# Epoch 10/50
#   1/390 ━━━━━━━━━━━━━━━━━━━━ 5:11 801ms/step - accuracy: 0.6016 - loss: 1.1123
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.6016 - loss: 1.1123 - val_accuracy: 0.6891 - val_loss: 0.8815
# Epoch 11/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - accuracy: 0.6573 - loss: 0.9780
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 418s 993ms/step - accuracy: 0.6573 - loss: 0.9780 - val_accuracy: 0.7096 - val_loss: 0.8225
# Epoch 12/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.6562 - loss: 0.9689 - val_accuracy: 0.7067 - val_loss: 0.8295
# Epoch 13/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.6734 - loss: 0.9290
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 423s 999ms/step - accuracy: 0.6734 - loss: 0.9290 - val_accuracy: 0.7384 - val_loss: 0.7559
# Epoch 14/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.6797 - loss: 0.9090 - val_accuracy: 0.7364 - val_loss: 0.7620
# Epoch 15/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 387s 992ms/step - accuracy: 0.6918 - loss: 0.8809 - val_accuracy: 0.7378 - val_loss: 0.7541
# Epoch 16/50
#   1/390 ━━━━━━━━━━━━━━━━━━━━ 8:06 1s/step - accuracy: 0.6797 - loss: 1.0114
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.6797 - loss: 1.0114 - val_accuracy: 0.7385 - val_loss: 0.7540
# Epoch 17/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - accuracy: 0.6982 - loss: 0.8534
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 422s 999ms/step - accuracy: 0.6982 - loss: 0.8533 - val_accuracy: 0.7501 - val_loss: 0.7288
# Epoch 18/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.8125 - loss: 0.6457 - val_accuracy: 0.7446 - val_loss: 0.7494
# Epoch 19/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 424s 1s/step - accuracy: 0.7156 - loss: 0.8165 - val_accuracy: 0.7316 - val_loss: 0.7633
# Epoch 20/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.7344 - loss: 0.8409 - val_accuracy: 0.7356 - val_loss: 0.7595
# Epoch 21/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 388s 995ms/step - accuracy: 0.7156 - loss: 0.8078 - val_accuracy: 0.7279 - val_loss: 0.8108
# Epoch 22/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.6719 - loss: 0.8334 - val_accuracy: 0.7325 - val_loss: 0.7910
# Epoch 23/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.7296 - loss: 0.7647
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 423s 995ms/step - accuracy: 0.7296 - loss: 0.7647 - val_accuracy: 0.7676 - val_loss: 0.6806
# Epoch 24/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.6953 - loss: 0.7680 - val_accuracy: 0.7626 - val_loss: 0.6973
# Epoch 25/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 418s 989ms/step - accuracy: 0.7417 - loss: 0.7518 - val_accuracy: 0.7276 - val_loss: 0.8192
# Epoch 26/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.7578 - loss: 0.6958 - val_accuracy: 0.7364 - val_loss: 0.7858
# Epoch 27/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.7421 - loss: 0.7373
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 385s 988ms/step - accuracy: 0.7421 - loss: 0.7373 - val_accuracy: 0.7685 - val_loss: 0.6825
# Epoch 28/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.7031 - loss: 0.8703 - val_accuracy: 0.7677 - val_loss: 0.6829
# Epoch 29/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - accuracy: 0.7499 - loss: 0.7217
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 424s 996ms/step - accuracy: 0.7499 - loss: 0.7217 - val_accuracy: 0.7690 - val_loss: 0.6843
# Epoch 30/50
#   1/390 ━━━━━━━━━━━━━━━━━━━━ 5:20 823ms/step - accuracy: 0.7422 - loss: 0.6948
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.7422 - loss: 0.6948 - val_accuracy: 0.7720 - val_loss: 0.6830
# Epoch 31/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 440s 1s/step - accuracy: 0.7476 - loss: 0.7226 - val_accuracy: 0.7632 - val_loss: 0.6896
# Epoch 32/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.7422 - loss: 0.7048 - val_accuracy: 0.7627 - val_loss: 0.6911
# Epoch 33/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 947ms/step - accuracy: 0.7585 - loss: 0.7008
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.7585 - loss: 0.7008 - val_accuracy: 0.7837 - val_loss: 0.6456
# Epoch 34/50
#   1/390 ━━━━━━━━━━━━━━━━━━━━ 5:12 804ms/step - accuracy: 0.7734 - loss: 0.6137
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.7734 - loss: 0.6137 - val_accuracy: 0.7900 - val_loss: 0.6269
# Epoch 35/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 417s 991ms/step - accuracy: 0.7592 - loss: 0.6840 - val_accuracy: 0.7815 - val_loss: 0.6437
# Epoch 36/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.8438 - loss: 0.5513 - val_accuracy: 0.7706 - val_loss: 0.6850
# Epoch 37/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 390s 1s/step - accuracy: 0.7652 - loss: 0.6823 - val_accuracy: 0.7757 - val_loss: 0.6620
# Epoch 38/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.7969 - loss: 0.5587 - val_accuracy: 0.7792 - val_loss: 0.6528
# Epoch 39/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 984ms/step - accuracy: 0.7706 - loss: 0.6634
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.7706 - loss: 0.6634 - val_accuracy: 0.7991 - val_loss: 0.5820
# Epoch 40/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8125 - loss: 0.5482 - val_accuracy: 0.7991 - val_loss: 0.5854
# Epoch 41/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 387s 992ms/step - accuracy: 0.7742 - loss: 0.6561 - val_accuracy: 0.7669 - val_loss: 0.6877
# Epoch 42/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.8438 - loss: 0.4600 - val_accuracy: 0.7654 - val_loss: 0.6917
# Epoch 43/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 425s 997ms/step - accuracy: 0.7743 - loss: 0.6512 - val_accuracy: 0.7885 - val_loss: 0.6277
# Epoch 44/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.7734 - loss: 0.5548 - val_accuracy: 0.7839 - val_loss: 0.6384
# Epoch 45/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 421s 1s/step - accuracy: 0.7765 - loss: 0.6443 - val_accuracy: 0.7897 - val_loss: 0.6218
# Epoch 46/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.7266 - loss: 0.8102 - val_accuracy: 0.7801 - val_loss: 0.6533
# Epoch 47/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 421s 995ms/step - accuracy: 0.7789 - loss: 0.6380 - val_accuracy: 0.7942 - val_loss: 0.6166
# Epoch 48/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.7656 - loss: 0.6192 - val_accuracy: 0.7983 - val_loss: 0.6044
# Epoch 49/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 944ms/step - accuracy: 0.7807 - loss: 0.6383
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 423s 997ms/step - accuracy: 0.7807 - loss: 0.6383 - val_accuracy: 0.8040 - val_loss: 0.5826
# Epoch 50/50
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.7031 - loss: 0.6856 - val_accuracy: 0.8012 - val_loss: 0.5914
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.8058 - loss: 0.5856
# Test accuracy: 80.40%
# Visualizing some test predictions:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step
# Training complete! Model evaluated and visualized.

# %%
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/best_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model
from google.colab import drive

# Mount Drive again
drive.mount('/content/drive')

# Load the saved model
model = load_model('/content/drive/MyDrive/best_model.h5')

# Model is now ready for predictions
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np

# Example: Predict the first 5 images from the test set
predictions = model.predict(x_test[:5])
predicted_labels = np.argmax(predictions, axis=1)

print("Predicted labels:", predicted_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Predicted labels: [3 8 8 0 6]
